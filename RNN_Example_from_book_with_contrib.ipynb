# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import tensorflow as tf 

# %matplotlib inline

# %%
import utils as ut
early_stopping = ut.EarlyStopping(patience=100, verbose=1)

# %% [markdown]
# # 1. Create Data for Toy Problem

# %%
seed_int=123

rng = np.random.RandomState(seed_int)

def sin(x, T=100):
    return np.sin(2.0 * np.pi * x/T)

def toy_problem(T=100, ampl=0.05):
    x = np.arange(0, 2*T + 1)
    noise = ampl*rng.uniform(low = -1.0, high = 1.0, size=len(x))
    return sin(x) + noise

T = 100
f = toy_problem(T)
plt.plot(f)

# %% [markdown]
# # 2a. Prepare Input Data to Train the Model

# %%
length_of_sequences = 2*T
maxlen = 25
data = []
target = []

for i in range(0, length_of_sequences - maxlen + 1):
    data.append(f[i: i + maxlen])
    target.append(f[i + maxlen])

X = np.array(data).reshape(len(data), maxlen, 1)
Y = np.array(target).reshape(len(data), 1)

# %% [markdown]
# # 2b. Split Data into Training and Valdiation Set

# %%
N_train = int(len(data) * 0.9)
N_validation = len(data) - N_train
X_train, X_validation, Y_train, Y_validation = \
train_test_split(X, Y, test_size=N_validation, random_state=seed_int)

# %% [markdown]
# # 3. Prepare Model Functions for Graph

# %%
def weight_variable(shape, name=None):
    initial = tf.truncated_normal(shape, stddev=0.01) # resample 2 sd vals
    return tf.Variable(initial, name=name)
    
def bias_variable(shape, name=None):
    initial = tf.zeros(shape, dtype=tf.float32)
    return tf.Variable(initial, name=name)

# %%
def infere_mn(x, n_batch, maxlen=None, n_hidden=None, n_out=None, 
                n_in=None):
    V = weight_variable([n_hidden, n_out], 'V')
    U = weight_variable([n_in, n_hidden], 'U') # going to combine this as (x, U)
    W = weight_variable([n_hidden, n_hidden], 'W')
    b = bias_variable([n_hidden], 'b')
    c = bias_variable([n_out], 'c')

    with tf.variable_scope('RNN'):
        hlist = []
        h_prev = tf.zeros([n_batch, n_hidden], dtype=tf.float32)
        for i in range(maxlen):
            if i > 0:
                tf.get_variable_scope().reuse_variables()
                h_prev = hlist[-1]
            h_i = tf.tanh(tf.matmul(x[:, i, :], U) + tf.matmul(h_prev, W) + b)
            hlist.append(h_i)
    h_last = hlist[-1]
    y = tf.matmul(h_last, V) + c
    return y, [V, U, W, b, c]

def loss(y, t):
    mse = tf.reduce_mean(tf.square(y - t))
    return mse

def training(loss):
    optimize = tf.train.AdamOptimizer(learning_rate = 0.001, beta1=0.9, beta2=0.999)
    train_step = optimize.minimize(loss)
    return train_step

def inference_RNN(x, n_batch, maxlen=None, n_hidden=None, n_out=None, n_in=None):
    def weight_variable(shape):
        initial = tf.truncated_normal(shape, stddev=0.01) # resample 2 sd vals
        return tf.Variable(initial)
    
    def bias_variable(shape):
        initial = tf.zeros(shape, dtype=tf.float32)
        return tf.Variable(initial)
    
    cell = tf.contrib.rnn.BasicRNNCell(n_hidden)
    initial_state = cell.zero_state(n_batch, tf.float32)
    
    state = initial_state
    outputs = []
    with tf.variable_scope('RNN'):
        for t in range(maxlen):
            if t > 0:
                tf.get_variable_scope().reuse_variables()
            #    pass
            (cell_output, state) = cell(x[:, t, :], state)
            outputs.append(cell_output)
    output = outputs[-1]
    
    V = weight_variable([n_hidden, n_out])
    c = bias_variable([n_out])
    y = tf.matmul(output, V) + c
    
    return y, cell.variables

# %% [markdown]
# # 4. Define Graph

# %%
tf.reset_default_graph()

maxlen = 25
n_hidden = 20
n_out = 1
n_in = 1

x = tf.placeholder(tf.float32, shape=[None, maxlen, n_in])
t = tf.placeholder(tf.float32, shape=[None, n_out])
n_batch = tf.placeholder(tf.int32, [])

# TF Variables
#y = infere_mn(x, n_batch, maxlen=maxlen, n_hidden=n_hidden, n_out= n_out, n_in=n_in)
#y, cvars = infere_mn(x, n_batch, maxlen=maxlen, n_hidden=n_hidden, n_out= n_out, n_in=n_in)
y, cvars = inference_RNN(x, n_batch, maxlen=maxlen, n_hidden=n_hidden, n_out= n_out, n_in=n_in)
loss = loss(y, t)
train_step = training(loss)

# %% [markdown]
# # 5. Run Computational Graph

# %%
epochs = 1000
batch_size = 10

tf.set_random_seed(seed_int)
init = tf.global_variables_initializer()
sess = tf.Session()
sess.run(init)
history= {'val_loss': []}
n_batches = N_train // batch_size
early_stopping = ut.EarlyStopping(patience=100, verbose=1)
for epoch in range(epochs):
    X_, Y_ = shuffle(X_train, Y_train, random_state = seed_int)
    
    for i in range(n_batches):
        start = i*batch_size
        end = start + batch_size
        
        sess.run(train_step, feed_dict={
            x: X_[start:end],
            t: Y_[start:end],
            n_batch: batch_size
        })
    val_loss = loss.eval(session=sess, feed_dict={
        x: X_validation,
        t: Y_validation,
        n_batch: N_validation
    })
    history['val_loss'].append(val_loss)
    print('epoch:', epoch, ' validation loss: ', val_loss)
    #Early Stopping
    if early_stopping.validate(val_loss):
        break
# Out:
# epoch: 0  validation loss:  0.424126
# epoch: 1  validation loss:  0.275587
# epoch: 2  validation loss:  0.150487
# epoch: 3  validation loss:  0.0723188
# epoch: 4  validation loss:  0.0371811
# epoch: 5  validation loss:  0.0287683
# epoch: 6  validation loss:  0.0239523
# epoch: 7  validation loss:  0.0174811
# epoch: 8  validation loss:  0.0121196
# epoch: 9  validation loss:  0.00889696
# epoch: 10  validation loss:  0.00681014
# epoch: 11  validation loss:  0.00529194
# epoch: 12  validation loss:  0.00425062
# epoch: 13  validation loss:  0.00362741
# epoch: 14  validation loss:  0.00328491
# epoch: 15  validation loss:  0.0030951
# epoch: 16  validation loss:  0.00298362
# epoch: 17  validation loss:  0.00291254
# epoch: 18  validation loss:  0.00286485
# epoch: 19  validation loss:  0.00283528
# epoch: 20  validation loss:  0.00282114
# epoch: 21  validation loss:  0.00281995
# epoch: 22  validation loss:  0.00283158
# epoch: 23  validation loss:  0.00286691
# epoch: 24  validation loss:  0.00295395
# epoch: 25  validation loss:  0.00312539
# epoch: 26  validation loss:  0.00339125
# epoch: 27  validation loss:  0.00369587
# epoch: 28  validation loss:  0.00387177
# epoch: 29  validation loss:  0.00371598
# epoch: 30  validation loss:  0.00324384
# epoch: 31  validation loss:  0.00271815
# epoch: 32  validation loss:  0.00234198
# epoch: 33  validation loss:  0.00214242
# epoch: 34  validation loss:  0.00207782
# epoch: 35  validation loss:  0.00211165
# epoch: 36  validation loss:  0.00221802
# epoch: 37  validation loss:  0.00236367
# epoch: 38  validation loss:  0.00249026
# epoch: 39  validation loss:  0.00252346
# epoch: 40  validation loss:  0.00242668
# epoch: 41  validation loss:  0.00224339
# epoch: 42  validation loss:  0.00205736
# epoch: 43  validation loss:  0.00192436
# epoch: 44  validation loss:  0.00185632
# epoch: 45  validation loss:  0.00184191
# epoch: 46  validation loss:  0.00186294
# epoch: 47  validation loss:  0.0018999
# epoch: 48  validation loss:  0.00193357
# epoch: 49  validation loss:  0.00194826
# epoch: 50  validation loss:  0.0019366
# epoch: 51  validation loss:  0.00190206
# epoch: 52  validation loss:  0.00185596
# epoch: 53  validation loss:  0.00181091
# epoch: 54  validation loss:  0.00177555
# epoch: 55  validation loss:  0.00175299
# epoch: 56  validation loss:  0.00174192
# epoch: 57  validation loss:  0.00173855
# epoch: 58  validation loss:  0.00173834
# epoch: 59  validation loss:  0.00173725
# epoch: 60  validation loss:  0.00173264
# epoch: 61  validation loss:  0.00172364
# epoch: 62  validation loss:  0.00171092
# epoch: 63  validation loss:  0.00169606
# epoch: 64  validation loss:  0.00168085
# epoch: 65  validation loss:  0.00166672
# epoch: 66  validation loss:  0.00165442
# epoch: 67  validation loss:  0.00164404
# epoch: 68  validation loss:  0.00163514
# epoch: 69  validation loss:  0.00162712
# epoch: 70  validation loss:  0.00161932
# epoch: 71  validation loss:  0.00161126
# epoch: 72  validation loss:  0.00160269
# epoch: 73  validation loss:  0.00159363
# epoch: 74  validation loss:  0.00158425
# epoch: 75  validation loss:  0.00157478
# epoch: 76  validation loss:  0.00156544
# epoch: 77  validation loss:  0.00155638
# epoch: 78  validation loss:  0.00154767
# epoch: 79  validation loss:  0.00153929
# epoch: 80  validation loss:  0.00153119
# epoch: 81  validation loss:  0.00152328
# epoch: 82  validation loss:  0.00151553
# epoch: 83  validation loss:  0.00150787
# epoch: 84  validation loss:  0.00150029
# epoch: 85  validation loss:  0.00149282
# epoch: 86  validation loss:  0.00148545
# epoch: 87  validation loss:  0.00147821
# epoch: 88  validation loss:  0.00147114
# epoch: 89  validation loss:  0.00146424
# epoch: 90  validation loss:  0.00145753
# epoch: 91  validation loss:  0.00145097
# epoch: 92  validation loss:  0.00144459
# epoch: 93  validation loss:  0.00143837
# epoch: 94  validation loss:  0.0014323
# epoch: 95  validation loss:  0.00142638
# epoch: 96  validation loss:  0.00142061
# epoch: 97  validation loss:  0.00141498
# epoch: 98  validation loss:  0.0014095
# epoch: 99  validation loss:  0.00140416
# epoch: 100  validation loss:  0.00139896
# epoch: 101  validation loss:  0.00139391
# epoch: 102  validation loss:  0.001389
# epoch: 103  validation loss:  0.00138422
# epoch: 104  validation loss:  0.00137957
# epoch: 105  validation loss:  0.00137504
# epoch: 106  validation loss:  0.00137064
# epoch: 107  validation loss:  0.00136637
# epoch: 108  validation loss:  0.0013622
# epoch: 109  validation loss:  0.00135815
# epoch: 110  validation loss:  0.00135421
# epoch: 111  validation loss:  0.00135036
# epoch: 112  validation loss:  0.00134663
# epoch: 113  validation loss:  0.001343
# epoch: 114  validation loss:  0.00133945
# epoch: 115  validation loss:  0.001336
# epoch: 116  validation loss:  0.00133263
# epoch: 117  validation loss:  0.00132936
# epoch: 118  validation loss:  0.00132615
# epoch: 119  validation loss:  0.00132303
# epoch: 120  validation loss:  0.00131998
# epoch: 121  validation loss:  0.001317
# epoch: 122  validation loss:  0.0013141
# epoch: 123  validation loss:  0.00131126
# epoch: 124  validation loss:  0.00130848
# epoch: 125  validation loss:  0.00130576
# epoch: 126  validation loss:  0.0013031
# epoch: 127  validation loss:  0.0013005
# epoch: 128  validation loss:  0.00129795
# epoch: 129  validation loss:  0.00129545
# epoch: 130  validation loss:  0.001293
# epoch: 131  validation loss:  0.00129059
# epoch: 132  validation loss:  0.00128822
# epoch: 133  validation loss:  0.00128589
# epoch: 134  validation loss:  0.00128361
# epoch: 135  validation loss:  0.00128137
# epoch: 136  validation loss:  0.00127916
# epoch: 137  validation loss:  0.00127699
# epoch: 138  validation loss:  0.00127484
# epoch: 139  validation loss:  0.00127273
# epoch: 140  validation loss:  0.00127065
# epoch: 141  validation loss:  0.00126861
# epoch: 142  validation loss:  0.00126659
# epoch: 143  validation loss:  0.0012646
# epoch: 144  validation loss:  0.00126262
# epoch: 145  validation loss:  0.00126067
# epoch: 146  validation loss:  0.00125875
# epoch: 147  validation loss:  0.00125684
# epoch: 148  validation loss:  0.00125496
# epoch: 149  validation loss:  0.00125309
# epoch: 150  validation loss:  0.00125124
# epoch: 151  validation loss:  0.00124942
# epoch: 152  validation loss:  0.0012476
# epoch: 153  validation loss:  0.0012458
# epoch: 154  validation loss:  0.00124402
# epoch: 155  validation loss:  0.00124226
# epoch: 156  validation loss:  0.00124051
# epoch: 157  validation loss:  0.00123876
# epoch: 158  validation loss:  0.00123704
# epoch: 159  validation loss:  0.00123533
# epoch: 160  validation loss:  0.00123362
# epoch: 161  validation loss:  0.00123193
# epoch: 162  validation loss:  0.00123026
# epoch: 163  validation loss:  0.00122857
# epoch: 164  validation loss:  0.00122691
# epoch: 165  validation loss:  0.00122527
# epoch: 166  validation loss:  0.00122361
# epoch: 167  validation loss:  0.00122197
# epoch: 168  validation loss:  0.00122035
# epoch: 169  validation loss:  0.00121873
# epoch: 170  validation loss:  0.00121711
# epoch: 171  validation loss:  0.00121551
# epoch: 172  validation loss:  0.0012139
# epoch: 173  validation loss:  0.00121231
# epoch: 174  validation loss:  0.00121072
# epoch: 175  validation loss:  0.00120913
# epoch: 176  validation loss:  0.00120755
# epoch: 177  validation loss:  0.00120598
# epoch: 178  validation loss:  0.0012044
# epoch: 179  validation loss:  0.00120283
# epoch: 180  validation loss:  0.00120127
# epoch: 181  validation loss:  0.0011997
# epoch: 182  validation loss:  0.00119813
# epoch: 183  validation loss:  0.00119659
# epoch: 184  validation loss:  0.00119503
# epoch: 185  validation loss:  0.00119349
# epoch: 186  validation loss:  0.00119194
# epoch: 187  validation loss:  0.00119039
# epoch: 188  validation loss:  0.00118885
# epoch: 189  validation loss:  0.00118731
# epoch: 190  validation loss:  0.00118577
# epoch: 191  validation loss:  0.00118423
# epoch: 192  validation loss:  0.00118269
# epoch: 193  validation loss:  0.00118115
# epoch: 194  validation loss:  0.00117962
# epoch: 195  validation loss:  0.00117808
# epoch: 196  validation loss:  0.00117654
# epoch: 197  validation loss:  0.001175
# epoch: 198  validation loss:  0.00117347
# epoch: 199  validation loss:  0.00117192
# epoch: 200  validation loss:  0.00117038
# epoch: 201  validation loss:  0.00116885
# epoch: 202  validation loss:  0.0011673
# epoch: 203  validation loss:  0.00116576
# epoch: 204  validation loss:  0.00116422
# epoch: 205  validation loss:  0.00116268
# epoch: 206  validation loss:  0.00116114
# epoch: 207  validation loss:  0.00115959
# epoch: 208  validation loss:  0.00115804
# epoch: 209  validation loss:  0.00115648
# epoch: 210  validation loss:  0.00115493
# epoch: 211  validation loss:  0.00115338
# epoch: 212  validation loss:  0.00115183
# epoch: 213  validation loss:  0.00115028
# epoch: 214  validation loss:  0.00114871
# epoch: 215  validation loss:  0.00114716
# epoch: 216  validation loss:  0.0011456
# epoch: 217  validation loss:  0.00114404
# epoch: 218  validation loss:  0.00114248
# epoch: 219  validation loss:  0.00114092
# epoch: 220  validation loss:  0.00113937
# epoch: 221  validation loss:  0.00113781
# epoch: 222  validation loss:  0.00113624
# epoch: 223  validation loss:  0.00113468
# epoch: 224  validation loss:  0.00113313
# epoch: 225  validation loss:  0.00113158
# epoch: 226  validation loss:  0.00113003
# epoch: 227  validation loss:  0.00112849
# epoch: 228  validation loss:  0.00112695
# epoch: 229  validation loss:  0.00112541
# epoch: 230  validation loss:  0.00112388
# epoch: 231  validation loss:  0.00112235
# epoch: 232  validation loss:  0.00112083
# epoch: 233  validation loss:  0.00111932
# epoch: 234  validation loss:  0.00111781
# epoch: 235  validation loss:  0.00111632
# epoch: 236  validation loss:  0.00111483
# epoch: 237  validation loss:  0.00111335
# epoch: 238  validation loss:  0.0011119
# epoch: 239  validation loss:  0.00111044
# epoch: 240  validation loss:  0.001109
# epoch: 241  validation loss:  0.00110758
# epoch: 242  validation loss:  0.00110617
# epoch: 243  validation loss:  0.00110476
# epoch: 244  validation loss:  0.00110338
# epoch: 245  validation loss:  0.00110201
# epoch: 246  validation loss:  0.00110066
# epoch: 247  validation loss:  0.00109933
# epoch: 248  validation loss:  0.00109801
# epoch: 249  validation loss:  0.00109671
# epoch: 250  validation loss:  0.00109542
# epoch: 251  validation loss:  0.00109415
# epoch: 252  validation loss:  0.00109291
# epoch: 253  validation loss:  0.00109168
# epoch: 254  validation loss:  0.00109047
# epoch: 255  validation loss:  0.00108927
# epoch: 256  validation loss:  0.0010881
# epoch: 257  validation loss:  0.00108694
# epoch: 258  validation loss:  0.00108579
# epoch: 259  validation loss:  0.00108467
# epoch: 260  validation loss:  0.00108356
# epoch: 261  validation loss:  0.00108248
# epoch: 262  validation loss:  0.0010814
# epoch: 263  validation loss:  0.00108035
# epoch: 264  validation loss:  0.0010793
# epoch: 265  validation loss:  0.00107828
# epoch: 266  validation loss:  0.00107727
# epoch: 267  validation loss:  0.00107627
# epoch: 268  validation loss:  0.00107528
# epoch: 269  validation loss:  0.00107431
# epoch: 270  validation loss:  0.00107335
# epoch: 271  validation loss:  0.0010724
# epoch: 272  validation loss:  0.00107146
# epoch: 273  validation loss:  0.00107052
# epoch: 274  validation loss:  0.00106959
# epoch: 275  validation loss:  0.00106867
# epoch: 276  validation loss:  0.00106776
# epoch: 277  validation loss:  0.00106686
# epoch: 278  validation loss:  0.00106595
# epoch: 279  validation loss:  0.00106505
# epoch: 280  validation loss:  0.00106416
# epoch: 281  validation loss:  0.00106327
# epoch: 282  validation loss:  0.00106236
# epoch: 283  validation loss:  0.00106147
# epoch: 284  validation loss:  0.00106057
# epoch: 285  validation loss:  0.00105966
# epoch: 286  validation loss:  0.00105874
# epoch: 287  validation loss:  0.00105782
# epoch: 288  validation loss:  0.00105689
# epoch: 289  validation loss:  0.00105594
# epoch: 290  validation loss:  0.00105498
# epoch: 291  validation loss:  0.00105401
# epoch: 292  validation loss:  0.00105302
# epoch: 293  validation loss:  0.00105201
# epoch: 294  validation loss:  0.00105097
# epoch: 295  validation loss:  0.00104991
# epoch: 296  validation loss:  0.00104882
# epoch: 297  validation loss:  0.00104769
# epoch: 298  validation loss:  0.00104652
# epoch: 299  validation loss:  0.00104532
# epoch: 300  validation loss:  0.00104406
# epoch: 301  validation loss:  0.00104277
# epoch: 302  validation loss:  0.00104139
# epoch: 303  validation loss:  0.00103996
# epoch: 304  validation loss:  0.00103846
# epoch: 305  validation loss:  0.00103688
# epoch: 306  validation loss:  0.0010352
# epoch: 307  validation loss:  0.00103343
# epoch: 308  validation loss:  0.00103154
# epoch: 309  validation loss:  0.00102953
# epoch: 310  validation loss:  0.00102736
# epoch: 311  validation loss:  0.00102503
# epoch: 312  validation loss:  0.00102253
# epoch: 313  validation loss:  0.00101982
# epoch: 314  validation loss:  0.00101689
# epoch: 315  validation loss:  0.0010137
# epoch: 316  validation loss:  0.00101024
# epoch: 317  validation loss:  0.00100649
# epoch: 318  validation loss:  0.00100243
# epoch: 319  validation loss:  0.000998063
# epoch: 320  validation loss:  0.000993428
# epoch: 321  validation loss:  0.000988612
# epoch: 322  validation loss:  0.000983749
# epoch: 323  validation loss:  0.000979066
# epoch: 324  validation loss:  0.0009748
# epoch: 325  validation loss:  0.000971074
# epoch: 326  validation loss:  0.000967627
# epoch: 327  validation loss:  0.000963556
# epoch: 328  validation loss:  0.000957801
# epoch: 329  validation loss:  0.000950808
# epoch: 330  validation loss:  0.000946007
# epoch: 331  validation loss:  0.000948003
# epoch: 332  validation loss:  0.000958317
# epoch: 333  validation loss:  0.00097356
# epoch: 334  validation loss:  0.000987791
# epoch: 335  validation loss:  0.000996506
# epoch: 336  validation loss:  0.00099892
# epoch: 337  validation loss:  0.000997105
# epoch: 338  validation loss:  0.000993638
# epoch: 339  validation loss:  0.000990178
# epoch: 340  validation loss:  0.000987389
# epoch: 341  validation loss:  0.000985436
# epoch: 342  validation loss:  0.000984323
# epoch: 343  validation loss:  0.000984048
# epoch: 344  validation loss:  0.000984543
# epoch: 345  validation loss:  0.000985627
# epoch: 346  validation loss:  0.000987034
# epoch: 347  validation loss:  0.000988407
# epoch: 348  validation loss:  0.000989419
# epoch: 349  validation loss:  0.00098985
# epoch: 350  validation loss:  0.000989631
# epoch: 351  validation loss:  0.000988855
# epoch: 352  validation loss:  0.000987686
# epoch: 353  validation loss:  0.000986322
# epoch: 354  validation loss:  0.000984913
# epoch: 355  validation loss:  0.000983567
# epoch: 356  validation loss:  0.000982326
# epoch: 357  validation loss:  0.000981228
# epoch: 358  validation loss:  0.000980288
# epoch: 359  validation loss:  0.000979502
# epoch: 360  validation loss:  0.000978869
# epoch: 361  validation loss:  0.000978383
# epoch: 362  validation loss:  0.000978014
# epoch: 363  validation loss:  0.000977748
# epoch: 364  validation loss:  0.000977547
# epoch: 365  validation loss:  0.000977385
# epoch: 366  validation loss:  0.000977228
# epoch: 367  validation loss:  0.000977059
# epoch: 368  validation loss:  0.000976865
# epoch: 369  validation loss:  0.000976654
# epoch: 370  validation loss:  0.000976429
# epoch: 371  validation loss:  0.000976226
# epoch: 372  validation loss:  0.000976061
# epoch: 373  validation loss:  0.000975959
# epoch: 374  validation loss:  0.000975943
# epoch: 375  validation loss:  0.000976028
# epoch: 376  validation loss:  0.000976229
# epoch: 377  validation loss:  0.000976569
# epoch: 378  validation loss:  0.000977064
# epoch: 379  validation loss:  0.000977743
# epoch: 380  validation loss:  0.000978629
# epoch: 381  validation loss:  0.000979729
# epoch: 382  validation loss:  0.00098106
# epoch: 383  validation loss:  0.000982627
# epoch: 384  validation loss:  0.000984416
# epoch: 385  validation loss:  0.000986397
# epoch: 386  validation loss:  0.000988531
# epoch: 387  validation loss:  0.000990753
# epoch: 388  validation loss:  0.00099299
# epoch: 389  validation loss:  0.00099516
# epoch: 390  validation loss:  0.000997169
# epoch: 391  validation loss:  0.000998931
# epoch: 392  validation loss:  0.00100038
# epoch: 393  validation loss:  0.00100147
# epoch: 394  validation loss:  0.00100219
# epoch: 395  validation loss:  0.00100257
# epoch: 396  validation loss:  0.00100262
# epoch: 397  validation loss:  0.00100241
# epoch: 398  validation loss:  0.00100199
# epoch: 399  validation loss:  0.00100142
# epoch: 400  validation loss:  0.00100074
# epoch: 401  validation loss:  0.001
# epoch: 402  validation loss:  0.000999222
# epoch: 403  validation loss:  0.000998431
# epoch: 404  validation loss:  0.000997647
# epoch: 405  validation loss:  0.000996878
# epoch: 406  validation loss:  0.000996134
# epoch: 407  validation loss:  0.000995409
# epoch: 408  validation loss:  0.000994704
# epoch: 409  validation loss:  0.000994002
# epoch: 410  validation loss:  0.000993294
# epoch: 411  validation loss:  0.000992559
# epoch: 412  validation loss:  0.000991772
# epoch: 413  validation loss:  0.000990912
# epoch: 414  validation loss:  0.000989955
# epoch: 415  validation loss:  0.000988885
# epoch: 416  validation loss:  0.000987711
# epoch: 417  validation loss:  0.000986454
# epoch: 418  validation loss:  0.000985182
# epoch: 419  validation loss:  0.000983963
# epoch: 420  validation loss:  0.000982921
# epoch: 421  validation loss:  0.000982154
# epoch: 422  validation loss:  0.000981758
# epoch: 423  validation loss:  0.000981792
# epoch: 424  validation loss:  0.000982322
# epoch: 425  validation loss:  0.000983363
# epoch: 426  validation loss:  0.000984978
# epoch: 427  validation loss:  0.000987228
# epoch: 428  validation loss:  0.000990151
# epoch: 429  validation loss:  0.000993753
# epoch: 430  validation loss:  0.000997999
# epoch: 431  validation loss:  0.00100281
# early stopping

# %% [markdown]
# # 6. Show Results

# %%
truncate = maxlen
Z = X[:1]
original = [f[i] for i in range(maxlen)]
predicted = [None for i in range(maxlen)]

for i in range(length_of_sequences -maxlen +1):
    z_ = Z[-1:]
    y_ = y.eval(session=sess, feed_dict ={x: Z[-1:],
                                          n_batch: 1})
    sequence_ = np.concatenate((z_.reshape(maxlen, n_in)[1:], y_), axis=0)\
                               .reshape(1, maxlen, n_in)
    Z = np.append(Z, sequence_, axis=0)
    predicted.append(y_.reshape(-1))

plt.rc('font', family='serif')
plt.figure()
plt.plot(toy_problem(T, ampl=0), linestyle='dotted', color='#aaaaaa')
plt.plot(original, linestyle='dashed', color='black')
plt.plot(predicted, color='black')
plt.show()

# %% [markdown]
# # 7. Inspect Variables

# %% [markdown]
# #### What happened to the variables in RNN cell?

# %%
    W = cvars[0].eval(session=sess)
    bias = cvars[1].eval(session=sess)
    print(W.shape) # Note that the first part is from the input x, the second part
                   # From the hidden state
    print(bias.shape)

# %%
tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES)

# %%
W
