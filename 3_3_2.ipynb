# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

rng = np.random.RandomState(123)

d = 2     # 次元
N = 10    # 各パターンのデータ数
mean = 5

x1 = rng.randn(N, d) + np.array([0, 0])
x2 = rng.randn(N, d) + np.array([mean, mean])
xarr = np.concatenate((x1, x2), axis=0)

# %%
plt.scatter(x1[:, 0], x1[:, 1], marker='^')
plt.scatter(x2[:, 0], x2[:, 1], marker='o')
plt.plot([0, 4], [2, -2],'b')
plt.show()

# %%
for elem in range(N):
    x = x1[elem, 0]
    y = x1[elem, 1]
    val  = 1*((x + y -2) > 0)
    loss +=val
print(loss)

# %%
loss=0
for elem in range(N):
    x = x2[elem, 0]
    y = x2[elem, 1]
    val  = 1*((x + y -2) < 0)
    loss +=val
print(loss)

# %%
import tensorflow as tf

# %%
x = tf.placeholder(tf.float32)
y = tf.placeholder(tf.float32)
t = tf.placeholder(tf.float32)

a = tf.Variable([.9], dtype=tf.float32)
b = tf.Variable([-.3], dtype=tf.float32)

l = y - a*x - b

# %%
tarr = np.concatenate((-np.ones(N), np.ones(N)), axis=0)

# %%
loss = tf.reduce_sum((-tf.tanh(t*l) + 1)/2)
#loss = tf.reduce_sum((-tf.sign(t*l) + 1)/2)

#loss = tf.reduce_sum(tf.maximum(0.0, -t*l))
train_step = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)
sess.run([train_step, loss, a, b], {x: xarr[:, 0], y:xarr[:,1], t:tarr})
# Out:
# [None,
#  9.0,
#  array([ 0.89999998], dtype=float32),
#  array([-0.30000001], dtype=float32)]

# %%
for _ in range(20):
    sess.run(train_step, feed_dict={x: xarr[:, 0], y: xarr[:, 1], t: tarr})
    a_value = sess.run(a)[0]
    b_value = sess.run(b)[0]
    show_img(a_value, b_value)
    #print(sess.run([loss, a, b], {x: xarr[:, 0], y: xarr[:, 1], t: tarr}))

# %%
l = y - a*x - b
# Out:
# <tf.Tensor 'sub_1:0' shape=<unknown> dtype=float32>

# %%
plt.scatter(x1[:, 0], x1[:, 1], marker='^')
plt.scatter(x2[:, 0], x2[:, 1], marker='o')
#plt.plot([0, 4], [2, -2],'b')
plt.show()

# %%
def yval(x, aval=-1.69970, bval=7.62665987):
    return aval*x + bval

plt.scatter(x1[:, 0], x1[:, 1], marker='^')
plt.scatter(x2[:, 0], x2[:, 1], marker='o')
plt.plot([0, 4], [2, -2],'b')
plt.show()

# %%
def show_img(a,b):
    line_x = np.linspace(-2,6)
    line_y = a*line_x + b
    plt.plot(line_x, line_y,'b')
    plt.scatter(x1[:, 0], x1[:, 1], marker='^')
    plt.scatter(x2[:, 0], x2[:, 1], marker='o')
    plt.show()

# %%
show_img(out[2][0], out[3][0])

# %%
sess.run(init)
sess.run([train_step, loss, a, b], {x: xarr[:, 0], y:xarr[:,1], t:tarr})
# Out:
# [None,
#  9.0,
#  array([ 0.89999998], dtype=float32),
#  array([-0.30000001], dtype=float32)]

# %%
import pandas as pd

# %%
a1 = pd.DataFrame({'aps':[1.0, 5, 4, 5 ]})
a2 = pd.DataFrame({'aps':[100.0, 50, 40, 50 ]})
idx = pd.MultiIndex.from_product([a1.index, a2.index],
                             names=['number', 'color'])
pd.concat([a1.reindex(idx, level='number'), a2.reindex(idx, level='number')])
# Out:
#                 aps
# number color
# 0      0        1.0
#        1        1.0
#        2        1.0
#        3        1.0
# 1      0        5.0
#        1        5.0
#        2        5.0
#        3        5.0
# 2      0        4.0
#        1        4.0
#        2        4.0
#        3        4.0
# 3      0        5.0
#        1        5.0
#        2        5.0
#        3        5.0
# 0      0      100.0
#        1      100.0
#        2      100.0
#        3      100.0
# 1      0       50.0
#        1       50.0
#        2       50.0
#        3       50.0
# 2      0       40.0
#        1       40.0
#        2       40.0
#        3       40.0
# 3      0       50.0
#        1       50.0
#        2       50.0
#        3       50.0
